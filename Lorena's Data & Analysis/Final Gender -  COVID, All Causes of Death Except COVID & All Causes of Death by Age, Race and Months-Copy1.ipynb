# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import json
from scipy.stats import linregress

# %%
monthly_case="Monthly Male & Female Covid & All Causes Deaths.csv"
mon_read=pd.read_csv(monthly_case, low_memory=False)
mon_read
# race_case="Male & Female Race Deaths.csv"
# race_read=pd.read_csv(race_case, low_memory=False)
# race_read
# ages_case="Male & Female Age Group Deaths Total.csv"
# ages_read=pd.read_csv(ages_case, low_memory=False)
# ages_read
# Out:
#    Month  Male Deaths Covid  Female Deaths Covid  Male Deaths All Cause  \
# 0    Jan                  0                    0                 134148
# 1    Feb                  0                    0                 124546
# 2  March               3957                 2514                 138307
# 3  April              33097                27204                 165594
# 4    May              17570                16880                 143811
# 5   June               8107                 7114                 128736
# 6   July              14643                11280                 138210
# 7    Aug               7809                 6250                  91229
#
#    Female Deaths All Cause  Male Deaths All Cause except covid  \
# 0                   118241                              134148
# 1                   117603                              124546
# 2                   127870                              134350
# 3                   139042                              132497
# ...

# %%
df2 = mon_read[["Month","Male Deaths Covid","Female Deaths Covid"]]
df3 = mon_read[["Month","Male Deaths All Cause","Female Deaths All Cause"]]
df4=mon_read[["Month","Male Deaths Covid","Male Deaths All Cause"]]
df5=mon_read[["Month","Female Deaths Covid","Female Deaths All Cause"]]

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df2.plot(kind="bar", figsize=(20,5), stacked=True)

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(mon_read["Month"], rotation=90)

plt.title('Male vs Female COVID Deaths by Months')
plt.xlabel('Months')
plt.ylabel('Number of COVID Deaths')
plt.tight_layout()
# plt.savefig("Male & Female COVID Deaths by Months Stacked Bar.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df2.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(mon_read["Month"], rotation=90)

plt.title('Male vs Female COVID Deaths by Months')
plt.xlabel('Months')
plt.ylabel('Number of COVID Deaths')
plt.tight_layout()
plt.savefig("Male & Female COVID Deaths by Months Bar.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df2.plot(kind="line", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(mon_read["Month"], rotation=90)

plt.title('Male vs Female All Causes of Death by Months')
plt.xlabel('Months')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Male vs Female COVID Deaths by Months Line.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df3.plot(kind="line", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(mon_read["Month"], rotation=90)

plt.title('Male vs Female All Causes of Death by Months')
plt.xlabel('Months')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Male vs Female All Causes of Death by Months Line.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df3.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(mon_read["Month"], rotation=90)

plt.title('Male vs Female All Causes of Death by Months')
plt.xlabel('Months')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Male vs Female All Causes of Death by Months Bar.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df4.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(mon_read["Month"], rotation=90)

plt.title('Male: COVID vs All Causes of Death by Months')
plt.xlabel('Months')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Male: COVID vs All Causes of Death by Months Bar.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df4.plot(kind="line", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(mon_read["Month"], rotation=90)

plt.title('Male: COVID vs All Causes of Death by Months')
plt.xlabel('Months')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Male: COVID vs All Causes of Death by Months Line.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df5.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(mon_read["Month"], rotation=90)

plt.title('Female: COVID vs All Causes of Death by Months')
plt.xlabel('Months')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Female: COVID vs All Causes of Death by Months Bar.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df5.plot(kind="line", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(mon_read["Month"], rotation=90)

plt.title('Female: COVID vs All Causes of Death by Months')
plt.xlabel('Months')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Female: COVID vs All Causes of Death by Month Line.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = mon_read.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(mon_read["Month"], rotation=90)

plt.title('Female & Male: COVID, All Causes of Death & All Causes of Death Except COVID by Months')
plt.xlabel('Months')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Female & Male: COVID, All Causes of Death & All Causes of Death Except COVID by Months Bar.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = mon_read.plot(kind="line", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(mon_read["Month"], rotation=90)

plt.title('Female & Male: COVID, All Causes of Death & All Causes of Death Except COVID by Months')
plt.xlabel('Months')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Female & Male: COVID, All Causes of Death & All Causes of Death Except COVID by Months Line.png")
plt.show()

# %%
race_case="Male & Female Race Deaths.csv"
race_read=pd.read_csv(race_case, low_memory=False)
race_read
# ages_case="Male & Female Age Group Deaths Total.csv"
# ages_read=pd.read_csv(ages_case, low_memory=False)
# ages_read
# Out:
#                Race  Male Deaths Covid  Female Deaths Covid  \
# 0          Hispanic              21343                12461
# 1   Native American                759                  687
# 2             Asian               4115                 2802
# 3             White              40693                39372
# 4  African American              18273                15920
#
#    Male Deaths All Cause  Female Deaths All Cause  \
# 0                 106066                    78499
# 1                   7358                     6172
# 2                  29772                    27303
# 3                 776161                   739459
# 4                 145224                   129946
#
#    Male Deaths All Cause except covid  Female Deaths All Cause excep covid
# 0                               84723                                66038
# 1                                6599                                 5485
# ...

# %%
df2 = race_read[["Race","Male Deaths Covid","Female Deaths Covid"]]
df3 = race_read[["Race","Male Deaths All Cause","Female Deaths All Cause"]]
df4=race_read[["Race","Male Deaths Covid","Male Deaths All Cause"]]
df5=race_read[["Race","Female Deaths Covid","Female Deaths All Cause"]]

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df2.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(race_read["Race"], rotation=90)

plt.title('Male vs Female COVID Deaths by Race')
plt.xlabel('Race')
plt.ylabel('Number of COVID Deaths')
plt.tight_layout()
plt.savefig("Male vs Female COVID Deaths by Race Bar.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df2.plot(kind="line", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(race_read["Race"], rotation=90)

plt.title('Female vs. Male COVID Deaths by Race')
plt.xlabel('Race')
plt.ylabel('Number of COVID Deaths')
plt.tight_layout()
plt.savefig("Female vs. Male COVID Deaths by Race Line.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df3.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(race_read["Race"], rotation=90)

plt.title('Male vs Female: All Causes of Death by Race')
plt.xlabel('Race')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Male vs Female: All Causes of Death by Race Bar.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df3.plot(kind="line", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(race_read["Race"], rotation=90)

plt.title('Male vs Female: All Causes of Death by Race')
plt.xlabel('Race')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Male vs Female: All Causes of Death by Race Line.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df4.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(race_read["Race"], rotation=90)

plt.title('Male: COVID vs All Causes of Death by Race')
plt.xlabel('Race')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Male: COVID vs All Causes of Death by Race Bar.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df4.plot(kind="line", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(race_read["Race"], rotation=90)

plt.title('Male: COVID vs All Causes of Death by Race')
plt.xlabel('Race')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Male: COVID vs All Causes of Death by Race Line.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df5.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(race_read["Race"], rotation=90)

plt.title('Female: COVID vs All Causes of Death by Race')
plt.xlabel('Race')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Female: COVID vs All Causes of Death by Race Bar.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df5.plot(kind="line", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(race_read["Race"], rotation=90)

plt.title('Female: COVID vs All Causes of Death by Race')
plt.xlabel('Race')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Female: COVID vs All Causes of Death by Race Line.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = race_read.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(race_read["Race"], rotation=90)

plt.title('Female & Male: COVID vs All Causes of Death by Race')
plt.xlabel('Race')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Female & Male: COVID vs All Causes of Death by Race Bar.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = race_read.plot(kind="line", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(race_read["Race"], rotation=90)

plt.title('Female & Male: COVID vs All Causes of Death by Race')
plt.xlabel('Race')
plt.ylabel('Number of Deaths')
plt.tight_layout()
# plt.savefig("Female & Male: COVID vs All Causes of Death by Race Line.png")
plt.show()

# %%
ages_case="Male & Female Age Group Deaths Total.csv"
ages_read=pd.read_csv(ages_case, low_memory=False)
ages_read
# Out:
#            Age Group  Male Deaths Covid  Female Deaths Covid  \
# 0          0-4 years                  0                    0
# 1        15-24 years                 93                   30
# 2        25-34 years                764                  341
# 3        35-44 years               2141                  924
# 4        45-54 years               5813                 2632
# 5         5-14 years                  0                    0
# 6        55-64 years              13056                 6967
# 7        65-74 years              20957                12949
# 8        75-84 years              22917                18615
# 9  85 years and over              19442                28784
#
#    Male Deaths All Cause  Female Deaths All Cause  \
# 0                   7323                     5825
# 1                  15560                     5452
# 2                  30751                    12903
# 3                  40907                    20619
# ...

# %%
df2 = ages_read[["Age Group","Male Deaths Covid","Female Deaths Covid"]]
df3 = ages_read[["Age Group","Male Deaths All Cause","Female Deaths All Cause"]]
df4=ages_read[["Age Group","Male Deaths Covid","Male Deaths All Cause"]]
df5=ages_read[["Age Group","Female Deaths Covid","Female Deaths All Cause"]]

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df2.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(ages_read["Age Group"], rotation=90)

plt.title('Male vs Female COVID Deaths by Age Groups')
plt.xlabel('Age Groups')
plt.ylabel('Number of Deaths from COVID')
plt.tight_layout()
plt.savefig("Male vs Female COVID Deaths by Age Groups Bar.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df2.plot(kind="line", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(ages_read["Age Group"], rotation=90)

plt.title('Male vs Female COVID Deaths by Age Groups')
plt.xlabel('Age Groups')
plt.ylabel('Number of Deaths from COVID & All Causes')
plt.tight_layout()
plt.savefig("Male vs Female COVID Deaths by Age Groups Line.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df3.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(ages_read["Age Group"], rotation=90)

plt.title('Male vs Female All Causes of Death Age Groups')
plt.xlabel('Age Groups')
plt.ylabel('Number of Deaths from All Causes')
plt.tight_layout()
plt.savefig("Male vs Female All Causes of Death Age Groups Bar.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df3.plot(kind="line", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(ages_read["Age Group"], rotation=90)

plt.title('Male vs Female All Causes of Death Age Groups')
plt.xlabel('Age Groups')
plt.ylabel('Number of Deaths from All Causes')
plt.tight_layout()
plt.savefig("Male vs Female All Causes of Death Age Groups Line.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df4.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(ages_read["Age Group"], rotation=90)

plt.title('Male: COVID vs All Causes of Death Age Groups')
plt.xlabel('Age Groups')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Male: COVID vs All Causes of Death Age Groups Bar.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df4.plot(kind="line", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(ages_read["Age Group"], rotation=90)

plt.title('Male: COVID vs All Causes of Death Age Groups')
plt.xlabel('Age Groups')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Male: COVID vs All Causes of Death Age Groups Line.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df5.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(ages_read["Age Group"], rotation=90)

plt.title('Female: COVID vs All Causes of Death Age Groups')
plt.xlabel('Age Groups')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Male: COVID vs All Causes of Death Age Groups Bar.png")
plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df5.plot(kind="line", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(ages_read["Age Group"], rotation=90)

plt.title('Female: COVID vs All Causes of Death Age Groups')
plt.xlabel('Age Groups')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Female: COVID vs All Causes of Death Age Groups Line.png")
plt.show()

# %%
df6=ages_read[['Age Group','Male Deaths Covid','Female Deaths Covid','Male Deaths All Cause','Female Deaths All Cause','Male Death All Causes Except COVID','Female Death All Causes Except COVID']]
df7=ages_read[['Age Group','Covid Male Rate','Covid Female Death Rate','Male All Cause Death Rate','Female All Cause Death Rate','Male All Cause Except COVID Death Rate','Female All Cause Except COVID Death Rate']]

# %%
#  Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df6.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(ages_read["Age Group"], rotation=90)

plt.title('Female & Male: COVID, All Causes of Death & All Causes of Death Except COVID Deaths by Age Groups')
plt.xlabel('Age Groups')
plt.ylabel('Number of Deaths')
plt.tight_layout()
plt.savefig("Female & Male: COVID, All Causes of Death & All Causes Except COVID Deaths by Age Groups")
plt.show()

# %%
#  Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = df7.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(ages_read["Age Group"], rotation=90)

plt.title('Female & Male: COVID, All Causes of Death & All Causes of Death Except COVID Death Rates by Age Groups')
plt.xlabel('Age Groups')
plt.ylabel('Death Rates')
plt.tight_layout()
plt.savefig("Female & Male: COVID, All Causes of Death & All Causes of Death Except COVID Death Rates by Age Groups")
plt.show()

# %%
# # Pandas can also plot multiple columns if the DataFrame includes them
# multi_plot = ages_read.plot(kind="bar", figsize=(20,5))

# # PandasPlot.set_xticklabels() can be used to set the tick labels as well
# multi_plot.set_xticklabels(ages_read["Age Group"], rotation=90)

# plt.title('Male & Female: COVID vs All Cause of Deaths by Age Groups')
# plt.xlabel('Age Groups')
# plt.ylabel('Number of Deaths')
# plt.tight_layout()
# plt.savefig("Male & Female: COVID vs All Cause of Deaths by Age Groups Bar.png")
# plt.show()

# %%
# # Pandas can also plot multiple columns if the DataFrame includes them
# multi_plot = ages_read.plot(kind="line", figsize=(20,5))

# # PandasPlot.set_xticklabels() can be used to set the tick labels as well
# multi_plot.set_xticklabels(ages_read["Age Group"], rotation=90)

# plt.title('Male & Female: COVID vs All Cause of Deaths by Age Groups')
# plt.xlabel('Age Groups')
# plt.ylabel('Number of Deaths')
# plt.tight_layout()
# plt.savefig("Male & Female: COVID vs All Cause of Deaths by Age Groups Line.png")
# plt.show()
